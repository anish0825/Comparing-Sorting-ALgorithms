# %%
n=int(input('Enter the number of random elements you want = '))


import random
mylist = []

for i in range(0,n):
    x = random.randint(1,100000)
    mylist.append(x)
    
new_list=mylist.copy()

# %%
#------------Insertion Sort Code--------------
def iSort( a):
    for j in range(1,len(a)):
        key=a[j]
        i=j-1
        while i>=0:
            if key<a[i]:
                a[i+1]=a[i]
                a[i]=key
                i-=1
            else:
                break
    return a



#-----------Merge Sort Code----------
def mergeSort(a): 
        if len(a) >1: 
            mid = len(a)//2 
            Left_a = a[:mid]   
            Right_a = a[mid:] 
            mergeSort(Left_a)  
            mergeSort(Right_a) 
  
            i = j = k = 0

             
            while i < len(Left_a) and j < len(Right_a): 
                if Left_a[i] < Right_a[j]: 
                    a[k] = Left_a[i] 
                    i+=1
                else: 
                    a[k] = Right_a[j] 
                    j+=1
                k+=1

             
            while i < len(Left_a): 
                a[k] = Left_a[i] 
                i+=1
                k+=1

            while j < len(Right_a): 
                a[k] = Right_a[j] 
                j+=1
                k+=1
        return a        

    
#-----Vector based Heap Sort ---------    
def Heap_order(arr, n, i): 
    largest = i   
    l = 2 * i + 1     
    r = 2 * i + 2      
    if l < n and arr[i] < arr[l]: 
        largest = l 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i]   
        Heap_order(arr, n, largest) 

        
def heapsort(arr): 
    n = len(arr) 
    for i in range(n, -1, -1): 
        Heap_order(arr, n, i) 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i]    
        Heap_order(arr, i, 0)
    
    
    
#----------------Inplace Quicksort---------------  
def divide(arr, low, high, piv):
    arr[low], arr[piv] = arr[piv], arr[low]
    pivot = arr[low]
    i = low + 1
    j = low + 1

    while j <= high:
        if arr[j] <= pivot:
            arr[j], arr[i] = arr[i], arr[j]
            i += 1
        j += 1

    arr[low], arr[i - 1] = arr[i - 1], arr[low]
    return i - 1

def quicksort(arr, low, high):

    if high - low < 1:
        return

    piv = random.randint(low, high)
    i = divide(arr, low, high, piv)
    quicksort(arr, low, i - 1)
    quicksort(arr, i + 1, high)
    

#------Modified Quicksort----------------
def divide(array, start, end, idx_pivot):
    array[start], array[idx_pivot] = array[idx_pivot], array[start]
    pivot = array[start]
    i = start + 1
    j = start + 1

    while j <= end:
        if array[j] <= pivot:
            array[j], array[i] = array[i], array[j]
            i += 1
        j += 1

    array[start], array[i - 1] = array[i - 1], array[start]
    return i-1
   
def MedianOfThree(array, start, end):
    mid = (start + end)//2
    if array[end] < array[start]:
        array[end], array[start] =  array[start],  array[end]    
    if array[mid] < array[start]:
        array[mid], array[start] =  array[start],  array[mid]
    if array[end] < array[mid]:
        array[end], array[mid] =  array[mid],  array[end]
    return mid    

def iSort_modified( array, start, end):
    for j in range(1,end):
        key=array[j]
        i=j-1
        while i>=0:
            if key<array[i]:
                array[i+1]=array[i]
                array[i]=key
                i-=1
            else:
                break

def modified_quicksort(array, start, end):
    if end is None:
        end = len(array) - 1
    if end - start < 1:
        return
    idx_pivot = MedianOfThree(array, start, end)
    i = divide(array, start, end, idx_pivot)
    
    if (i-1-start <= 10):
        iSort_modified(array, start, i)
    else:
        quicksort(array, start, i-1)

    if (end-i-1 <= 10):
        iSort_modified(array, i+1, end)
    else:
        modified_quicksort(array, i+1, end)

# %%
#Normal Insertion Sort
import time
start = time.time()
iSort(mylist)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting already Sorted Case
start = time.time()
iSort(mylist)
end = time.time()

print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Reverse sorted elements
start = time.time()
iSort(mylist[::-1])
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)


mylist = new_list.copy()

# %%
#Normal Merge Sort
start = time.time()
mergeSort(mylist)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting already sorted 
start = time.time()
mergeSort(mylist)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Reverse Sorted elements
start = time.time()
mergeSort(mylist[::-1])
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)


mylist = new_list.copy()

# %%
#Normal inplace quicksort
start = time.time()
quicksort(mylist,0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Already sorted Case
start = time.time()
quicksort(mylist,0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting reverse sorted elements
start = time.time()
quicksort(mylist[::-1],0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

mylist=new_list

# %%
#Normal Heap Sort
start = time.time()
heapsort(mylist)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Already Sorted Case
start = time.time()
heapsort(mylist)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Reverse Sorted Elements
start = time.time()
heapsort(mylist[::-1])
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

mylist=new_list

# %%
#Normal Sorting using modified quicksort
start = time.time()
modified_quicksort(mylist,0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting Already Sorted Case
start = time.time()
modified_quicksort(mylist,0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

# %%
#Sorting reverse Sorted Elements
start = time.time()
modified_quicksort(mylist[::-1],0,len(mylist)-1)
end = time.time()
print('Time in ms= ',(end - start)*1000)
print(mylist)

mylist=new_list
